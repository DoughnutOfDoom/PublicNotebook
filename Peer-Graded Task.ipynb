# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Maria Goryacheva__
#
# Copywriter

# %% [markdown]
# _I am interested in data science because I see a great use for it, and I think it is largerly going to shape our future._

# %% [markdown]
# ### The code below lets us replace variables with words in a sentence. Assign your own words to the variables, and try this for yourself!

# %%
first_name = "Maria"
asset_type = "Jupyter Notebook"
print (f"Hi, my name is {first_name}. This is my {asset_type}.")
# Out:
# Hi, my name is Maria. This is my Jupyter Notebook.

# %% [markdown]
#  - There was an Old Man with a beard
#  - Who said, "It's just as I feared! -
#  - Two Owls and a Hen,
#  - Four Larks and a Wren,
#  - Have all built their nests in my beard"
#  ***
#  1. You
#  2. Are
#  3. Doing
#  4. Amazing
#  ***
#  [Listen to my favourite song on Spotify!](https://open.spotify.com/track/7a7ZttJIaX2BHi8zO7vceC?si=54ccfab6524e42a7)
#  ***
#  ![np_Spring%20flowers%20and%20leaves%20coming%20out%20of%20pink%20house_5kvl30_large.jpg](attachment:np_Spring%20flowers%20and%20leaves%20coming%20out%20of%20pink%20house_5kvl30_large.jpg)
#  Thank you for <del>coming to my TED talk</del> reading my Notebook!
